# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
data = pd.read_csv('../openreview.csv')
binary_decisions = {'Accept (Oral)':1, 'Accept (Poster)':1, 'Accept (Spotlight)':1, 'Accept (Talk)':1, 'Withdrawn':0, 'Reject':0, 'Invite to Workshop Track':0}
mideast = ['bh', 'cy', 'eg','ir','iq','il','jo', 'kw','lb','om','ps','qa','sa','sy','tr','ae','ye']
eastasian = ['cn', 'jp', 'mn', 'kp','kr', 'tw', 'hk']
southasian = ['af','bd','bt', 'in', 'np', 'pk', 'lk','mv','sg']

# %%
def logistic_regression(prediction, mean_reviewer_score, country):
    scores =[]
    COO_indicator=[]
    target=[]
    print(country)

    for rating, decision, COO, region in zip(data['ratings'], data['decisions'], data['COO'], data['regions']):
        if country == 'US':
            if region == 'usa': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'Canada':
            if region == 'canada': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'South America':
            if region == 'southamerica': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'Australia and New Zealand':
            if COO == 'au' or COO == 'nz': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'Mid East':
            if COO in mideast: COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'UK/Ireland':
            if COO == 'uk' or COO == 'ie': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'mainland Europe':
            if region == 'europe': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'Russia':
            if COO == 'russia': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'Africa':
            if region == 'africa': COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'East Asian':
            if COO in eastasian: COO_indicator.append(1)
            else: COO_indicator.append(0)
        elif country == 'South Asia':
            if COO in southasian: COO_indicator.append(1)
            else: COO_indicator.append(0)
        else:
            print('cannot recognize input country')

        avg_rating=0
        for i in rating.split(';'):
            avg_rating += int(i)
        scores.append(avg_rating/len(rating.split(';')))

        target.append(binary_decisions[decision])

    x=pd.DataFrame()
    x['mean reviewer score']=scores
    x['COO']=COO_indicator
    x['constant']=[1]*len(scores)
    y=np.array(target)

    if country == 'Africa': return 'no data for Africa', None
    logit_model = sm.Logit(y, x)
    summary = logit_model.fit().summary()

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.3, random_state=0)
    logisticRegr = LogisticRegression(random_state=0)
    model = logisticRegr.fit(x_train, y_train)
    accuracy = logisticRegr.score(x_test, y_test)

    if prediction:
        input_list = [mean_reviewer_score, 1, 1]
        pred = np.array(input_list)
        y_pred = model.predict_proba(pred.reshape(1,-1))
        input_list2 = [mean_reviewer_score, 0, 1]
        pred = np.array(input_list2)
        y_pred2 = model.predict_proba(pred.reshape(1,-1))
        print('From country: ', y_pred)
        print('Not from country: ', y_pred2)

    return summary, accuracy

# %%
def logistic_regression2():
    scores =[]
    us_indicator=[]
    canada_indicator=[]
    south_america_indicator=[]
    aunz_indicator=[]
    mideast_indicator=[]
    ukireland_indicator=[]
    mainland_europe_indicator=[]
    russia_indicator=[]
    africa_indicator=[]
    east_asian_indicator=[]
    south_asia_indicator=[]
    target=[]

    for rating, decision, COO, region in zip(data['ratings'], data['decisions'], data['COO'], data['regions']):
        print(region)
        print(region=='NAN')
        if region !='NAN':
            if region == 'usa':
                us_indicator.append(1)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif region == 'canada':
                us_indicator.append(0)
                canada_indicator.append(1)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif region == 'southamerica': 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(1)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif COO == 'au' or COO == 'nz': 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(1)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif COO in mideast: 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(1)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif COO == 'uk' or COO == 'ie': 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(1)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif region == 'europe': 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(1)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif COO == 'russia': 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(1)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif region == 'africa': 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(1)
                east_asian_indicator.append(0)
                south_asia_indicator.append(0)
            elif COO in eastasian: 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(1)
                south_asia_indicator.append(0)
            elif COO in southasian: 
                us_indicator.append(0)
                canada_indicator.append(0)
                south_america_indicator.append(0)
                aunz_indicator.append(0)
                mideast_indicator.append(0)
                ukireland_indicator.append(0)
                mainland_europe_indicator.append(0)
                russia_indicator.append(0)
                africa_indicator.append(0)
                east_asian_indicator.append(0)
                south_asia_indicator.append(1)
            else:
                print('cannot recognize input country')

        avg_rating=0
        for i in rating.split(';'):
            avg_rating += int(i)
        scores.append(avg_rating/len(rating.split(';')))
        target.append(binary_decisions[decision])

    x=pd.DataFrame()
    x['us indicator']=us_indicator
    x['canada indicator']=canada_indicator
    x['south america indicator']=south_america_indicator
    x['AU/NZ indicator']=aunz_indicator
    x['mideast indicator']=mideast_indicator
    x['uk/ireland indicator']=ukireland_indicator
    x['mainland europe indicator']=mainland_europe_indicator
    x['russia indicator']=russia_indicator
    x['africa indicator']=africa_indicator
    x['east asia indicator']=east_asian_indicator
    x['south asia indicator'] = south_america_indicator
    x['constant']=[1]*len(us_indicator)
    x['mean reviewer score']=scores
    y=np.array(target)

    #if country == 'Africa': return 'no data for Africa', None
    logit_model = sm.Logit(y, x)
    summary = logit_model.fit().summary()

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.3, random_state=0)
    logisticRegr = LogisticRegression(random_state=0)
    model = logisticRegr.fit(x_train, y_train)
    accuracy = logisticRegr.score(x_test, y_test)


    return summary, accuracy

# %%
summary, score = logistic_regression2()
print(summary)
print('Accuracy: ', score, '\n')
'''countries = ['US', 'Canada', 'South America', 'Australia and New Zealand', 'Mid East', 'UK/Ireland', 'mainland Europe', 'Russia', 'Africa', 'East Asian', 'South Asia']
for country in countries:
    #summary, score = logistic_regression(True, 6.0, country)
    summary, score = logistic_regression2()
    print(summary)
    print('Accuracy: ', score, '\n')'''
# Out:
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# europe
# False
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# canada
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# canada
# False
# usa
# False
# usa
# False
# canada
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# canada
# False
# usa
# False
# NAN
# True
# australasia
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# canada
# False
# europe
# False
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# canada
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# usa
# False
# asia
# False
# NAN
# True
# canada
# False
# NAN
# True
# australasia
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# australasia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# canada
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# asia
# False
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# canada
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# australasia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# canada
# False
# NAN
# True
# canada
# False
# europe
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# australasia
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# australasia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# canada
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# europe
# False
# europe
# False
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# canada
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# canada
# False
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# canada
# False
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# australasia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# australasia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# australasia
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# canada
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# asia
# False
# canada
# False
# NAN
# True
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# australasia
# False
# europe
# False
# canada
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# canada
# False
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# asia
# False
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# australasia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# asia
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# canada
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# europe
# False
# canada
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# canada
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# australasia
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# canada
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# australasia
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# southamerica
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# usa
# False
# usa
# False
# europe
# False
# canada
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# asia
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# canada
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# australasia
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# australasia
# False
# usa
# False
# canada
# False
# australasia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# europe
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# europe
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# canada
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# australasia
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# asia
# False
# asia
# False
# australasia
# False
# europe
# False
# europe
# False
# usa
# False
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# southamerica
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# canada
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# australasia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# canada
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# canada
# False
# australasia
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# australasia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# europe
# False
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# canada
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# europe
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# canada
# False
# NAN
# True
# usa
# False
# australasia
# False
# usa
# False
# usa
# False
# europe
# False
# asia
# False
# usa
# False
# canada
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# australasia
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# canada
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# asia
# False
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# australasia
# False
# NAN
# True
# asia
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# canada
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# europe
# False
# usa
# False
# europe
# False
# southamerica
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# canada
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# australasia
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# canada
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# canada
# False
# australasia
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# europe
# False
# NAN
# True
# usa
# False
# canada
# False
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# southamerica
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# australasia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# canada
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# australasia
# False
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# canada
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# canada
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# australasia
# False
# NAN
# True
# europe
# False
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# canada
# False
# asia
# False
# canada
# False
# europe
# False
# australasia
# False
# usa
# False
# europe
# False
# asia
# False
# canada
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# europe
# False
# canada
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# asia
# False
# europe
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# australasia
# False
# NAN
# True
# usa
# False
# canada
# False
# europe
# False
# europe
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# southamerica
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# canada
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# southamerica
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# australasia
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# canada
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# asia
# False
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# australasia
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# australasia
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# canada
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# europe
# False
# usa
# False
# europe
# False
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# canada
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# australasia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# australasia
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# australasia
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# usa
# False
# europe
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# australasia
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# canada
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# asia
# False
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# australasia
# False
# canada
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# canada
# False
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# southamerica
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# canada
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# canada
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# southamerica
# False
# europe
# False
# usa
# False
# canada
# False
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# canada
# False
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# asia
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# canada
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# canada
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# southamerica
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# australasia
# False
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# australasia
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# canada
# False
# usa
# False
# australasia
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# australasia
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# asia
# False
# europe
# False
# NAN
# True
# asia
# False
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# asia
# False
# australasia
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# canada
# False
# NAN
# True
# NAN
# True
# asia
# False
# australasia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# canada
# False
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# australasia
# False
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# europe
# False
# asia
# False
# europe
# False
# ...
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# canada
# False
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# europe
# False
# NAN
# True
# europe
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# europe
# False
# asia
# False
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# canada
# False
# usa
# False
# canada
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# asia
# False
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# canada
# False
# europe
# False
# NAN
# True
# usa
# False
# canada
# False
# usa
# False
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# europe
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# australasia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# canada
# False
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# asia
# False
# asia
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# australasia
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# europe
# False
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# canada
# False
# usa
# False
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# asia
# False
# asia
# False
# europe
# False
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# australasia
# False
# europe
# False
# canada
# False
# europe
# False
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# europe
# False
# asia
# False
# australasia
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# europe
# False
# canada
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# asia
# False
# australasia
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# canada
# False
# NAN
# True
# usa
# False
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# europe
# False
# usa
# False
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# usa
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# europe
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# asia
# False
# australasia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# australasia
# False
# asia
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# europe
# False
# usa
# False
# canada
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# europe
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# europe
# False
# NAN
# True
# canada
# False
# europe
# False
# NAN
# True
# asia
# False
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# asia
# False
# australasia
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# europe
# False
# asia
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# canada
# False
# asia
# False
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# usa
# False
# NAN
# True
# asia
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# australasia
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# NAN
# True
# australasia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# canada
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# canada
# False
# NAN
# True
# NAN
# True
# europe
# False
# NAN
# True
# canada
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# usa
# False
# asia
# False
# canada
# False
# asia
# False
# NAN
# True
# europe
# False
# europe
# False
# asia
# False
# canada
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# europe
# False
# usa
# False
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# canada
# False
# europe
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# asia
# False
# NAN
# True
# usa
# False
# canada
# False
# asia
# False
# NAN
# True
# europe
# False
# usa
# False
# NAN
# True
# europe
# False
# NAN
# True
# asia
# False
# usa
# False
# NAN
# True
# asia
# False
# europe
# False
# europe
# False
# NAN
# True
# usa
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# asia
# False
# europe
# False
# europe
# False
# europe
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# canada
# False
# usa
# False
# NAN
# True
# asia
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# europe
# False
# europe
# False
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# NAN
# True
# australasia
# False
# NAN
# True
# NAN
# True
# asia
# False
# NAN
# True
# NAN
# True
# usa
# False
# usa
# False
# NAN
# True
# NAN
# True
# asia
# False
# europe
# False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4r/m83vp3l96r70s7dlr1lls7qh0000gn/T/ipykernel_19896/2101132242.py in <module>
# ----> 1 summary, score = logistic_regression2()
#       2 print(summary)
#       3 print('Accuracy: ', score, '\n')
#       4 '''countries = ['US', 'Canada', 'South America', 'Australia and New Zealand', 'Mid East', 'UK/Ireland', 'mainland Europe', 'Russia', 'Africa', 'East Asian', 'South Asia']
#       5 for country in countries:
#
# /var/folders/4r/m83vp3l96r70s7dlr1lls7qh0000gn/T/ipykernel_19896/1640962086.py in logistic_regression2()
#     172     x['south asia indicator'] = south_america_indicator
#     173     x['constant']=[1]*len(us_indicator)
# --> 174     x['mean reviewer score']=scores
#     175     y=np.array(target)
#     176
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     749     """
#     750     if len(data) != len(index):
# --> 751         raise ValueError(
#     752             "Length of values "
#     753             f"({len(data)}) "
#
# ValueError: Length of values (8553) does not match length of index (4623)
